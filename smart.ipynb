# %%
import pandas as pd
from utils import calc_data_size

df_ui = pd.read_csv("smart_ui.csv")
df_ui["size"] = df_ui.apply(
    lambda x: calc_data_size(
        x["start_year"],
        x["end_year"],
        x["max_lat"],
        x["min_lat"],
        x["max_lon"],
        x["min_lon"],
        x["temporal_resolution"],
        x["spatial_resolution"],
    ),
    axis=1,
)
print("Interested data size:", df_ui["size"].sum(), "GB")
df_ui
# Out:
# Interested data size: 1026.6881427168846 GB
#          variable  start_year  end_year  max_lat  min_lat  max_lon  min_lon  \
# 0     temperature        1981      2020       90        0        0     -180
# 1     temperature        1981      2020       90        0      180        0
# 2     temperature        1981      2020        0      -90        0     -180
# 3     temperature        1981      2020        0      -90      180        0
# 4     temperature        1941      1980       90        0        0     -180
# 5     temperature        1941      1980       90        0      180        0
# 6     temperature        1941      1980        0      -90        0     -180
# 7     temperature        1941      1980        0      -90      180        0
# 8   precipitation        1981      2020       90        0        0     -180
# 9   precipitation        1981      2020       90        0      180        0
# 10  precipitation        1981      2020        0      -90        0     -180
# 11  precipitation        1981      2020        0      -90      180        0
# 12  precipitation        1941      1980       90        0        0     -180
# 13  precipitation        1941      1980       90        0      180        0
# 14  precipitation        1941      1980        0      -90        0     -180
# 15  precipitation        1941      1980        0      -90      180        0
# 16       pressure        1981      2020       90        0        0     -180
# 17       pressure        1981      2020       90        0      180        0
# 18       pressure        1981      2020        0      -90        0     -180
# 19       pressure        1981      2020        0      -90      180        0
# 20       pressure        1941      1980       90        0        0     -180
# 21       pressure        1941      1980       90        0      180        0
# 22       pressure        1941      1980        0      -90        0     -180
# 23       pressure        1941      1980        0      -90      180        0
# 24           wind        1981      2020       90        0        0     -180
# 25           wind        1981      2020       90        0      180        0
# 26           wind        1981      2020        0      -90        0     -180
# 27           wind        1981      2020        0      -90      180        0
# 28           wind        1941      1980       90        0        0     -180
# 29           wind        1941      1980       90        0      180        0
# 30           wind        1941      1980        0      -90        0     -180
# 31           wind        1941      1980        0      -90      180        0
#
#    temporal_resolution  spatial_resolution  ui_id        size
# 0                 hour                0.25      1  140.201533
# 1                 hour                0.25      2  140.201533
# 2                  day                0.50      3    4.381298
# 3                  day                0.50      4    4.381298
# 4                month                0.50      5    0.144043
# 5                month                0.50      6    0.144043
# 6                 year                1.00      7    0.003001
# 7                 year                1.00      8    0.003001
# 8                 hour                0.25      9  140.201533
# 9                 hour                0.25     10  140.201533
# 10               month                0.50     11    0.144043
# 11               month                0.50     12    0.144043
# 12               month                0.50     13    0.144043
# 13               month                0.50     14    0.144043
# 14                year                1.00     15    0.003001
# 15                year                1.00     16    0.003001
# 16                hour                0.25     17  140.201533
# 17                hour                0.25     18  140.201533
# 18                 day                0.50     19    4.381298
# 19                 day                0.50     20    4.381298
# 20               month                0.50     21    0.144043
# 21               month                0.50     22    0.144043
# 22                year                1.00     23    0.003001
# 23                year                1.00     24    0.003001
# 24                hour                0.25     25  140.201533
# 25                 day                0.25     26   17.525192
# 26                 day                0.50     27    4.381298
# 27                 day                0.50     28    4.381298
# 28               month                0.50     29    0.144043
# 29               month                0.50     30    0.144043
# 30                year                1.00     31    0.003001
# 31                year                1.00     32    0.003001

# %%
from utils import create_metadata_from_ui

df_meta = create_metadata_from_ui(df_ui)
df_meta["file_size"] = df_meta.apply(
    lambda x: calc_data_size(
        x["start_year"],
        x["end_year"],
        x["max_lat"],
        x["min_lat"],
        x["max_lon"],
        x["min_lon"],
        x["actual_temporal_resolution"],
        x["actual_spatial_resolution"],
    ),
    axis=1,
)
print("Total data size after pre-aggregation", df_meta["file_size"].sum(), "GB")
df_meta
# Out:
# Total data size after pre-aggregation 2128.0564084276557 GB
#      ui_id     variable  start_year  end_year  max_lat  min_lat  max_lon  \
# 0        1  temperature        1981      2020       90        0        0
# 1        1  temperature        1981      2020       90        0        0
# 2        1  temperature        1981      2020       90        0        0
# 3        1  temperature        1981      2020       90        0        0
# 4        1  temperature        1981      2020       90        0        0
# ..     ...          ...         ...       ...      ...      ...      ...
# 172     30         wind        1941      1980       90        0      180
# 173     30         wind        1941      1980       90        0      180
# 174     30         wind        1941      1980       90        0      180
# 175     31         wind        1941      1980        0      -90        0
# 176     32         wind        1941      1980        0      -90      180
#
#      min_lon ui_temporal_resolution  ui_spatial_resolution  \
# 0       -180                   hour                   0.25
# 1       -180                   hour                   0.25
# 2       -180                   hour                   0.25
# 3       -180                   hour                   0.25
# 4       -180                   hour                   0.25
# ..       ...                    ...                    ...
# 172        0                  month                   0.50
# 173        0                  month                   0.50
# 174        0                  month                   0.50
# 175     -180                   year                   1.00
# 176        0                   year                   1.00
#
#     actual_temporal_resolution  actual_spatial_resolution   file_size
# 0                         hour                       0.25  140.201533
# 1                         hour                       0.50  105.151150
# 2                         hour                       1.00   26.287787
# 3                          day                       0.25   17.525192
# 4                          day                       0.50    4.381298
# ..                         ...                        ...         ...
# 172                      month                       1.00    0.036011
# 173                       year                       0.50    0.012004
# 174                       year                       1.00    0.003001
# 175                       year                       1.00    0.003001
# 176                       year                       1.00    0.003001
#
# [177 rows x 13 columns]

# %%
# See the ratio

import duckdb

sql = """
SELECT u.*, g.agg_size, g.agg_size / u.size as ratio
FROM df_ui u, (
    SELECT u.ui_id, sum(m.file_size) as agg_size
    FROM df_ui u, df_meta m
    WHERE u.ui_id = m.ui_id
    GROUP BY u.ui_id
) g
WHERE u.ui_id = g.ui_id
"""
df_ui_with_size = duckdb.query(sql).df()
ui_size = df_ui_with_size["size"].sum()
actual_size = df_ui_with_size["agg_size"].sum()
print("ui only size:", ui_size, "GB")
print("including pre-aggregation size:", actual_size, "GB")
print("ratio:", actual_size / ui_size)
df_ui_with_size
# Out:
# ui only size: 1026.6881427168846 GB
# including pre-aggregation size: 2128.0564084276557 GB
# ratio: 2.0727388579712858
#          variable  start_year  end_year  max_lat  min_lat  max_lon  min_lon  \
# 0     temperature        1981      2020       90        0        0     -180
# 1     temperature        1981      2020       90        0      180        0
# 2     temperature        1981      2020        0      -90        0     -180
# 3     temperature        1981      2020        0      -90      180        0
# 4     temperature        1941      1980       90        0        0     -180
# 5     temperature        1941      1980       90        0      180        0
# 6     temperature        1941      1980        0      -90        0     -180
# 7     temperature        1941      1980        0      -90      180        0
# 8   precipitation        1981      2020       90        0        0     -180
# 9   precipitation        1981      2020       90        0      180        0
# 10  precipitation        1981      2020        0      -90        0     -180
# 11  precipitation        1981      2020        0      -90      180        0
# 12  precipitation        1941      1980       90        0        0     -180
# 13  precipitation        1941      1980       90        0      180        0
# 14  precipitation        1941      1980        0      -90        0     -180
# 15  precipitation        1941      1980        0      -90      180        0
# 16       pressure        1981      2020       90        0        0     -180
# 17       pressure        1981      2020       90        0      180        0
# 18       pressure        1981      2020        0      -90        0     -180
# 19       pressure        1981      2020        0      -90      180        0
# 20       pressure        1941      1980       90        0        0     -180
# 21       pressure        1941      1980       90        0      180        0
# 22       pressure        1941      1980        0      -90        0     -180
# 23       pressure        1941      1980        0      -90      180        0
# 24           wind        1981      2020       90        0        0     -180
# 25           wind        1981      2020       90        0      180        0
# 26           wind        1981      2020        0      -90        0     -180
# 27           wind        1981      2020        0      -90      180        0
# 28           wind        1941      1980       90        0        0     -180
# 29           wind        1941      1980       90        0      180        0
# 30           wind        1941      1980        0      -90        0     -180
# 31           wind        1941      1980        0      -90      180        0
#
#    temporal_resolution  spatial_resolution  ui_id        size    agg_size  \
# 0                 hour                0.25      1  140.201533  295.461527
# 1                 hour                0.25      2  140.201533  295.461527
# 2                  day                0.50      3    4.381298    5.671680
# 3                  day                0.50      4    4.381298    5.671680
# 4                month                0.50      5    0.144043    0.195058
# 5                month                0.50      6    0.144043    0.195058
# 6                 year                1.00      7    0.003001    0.003001
# 7                 year                1.00      8    0.003001    0.003001
# 8                 hour                0.25      9  140.201533  295.461527
# 9                 hour                0.25     10  140.201533  295.461527
# 10               month                0.50     11    0.144043    0.195058
# 11               month                0.50     12    0.144043    0.195058
# 12               month                0.50     13    0.144043    0.195058
# 13               month                0.50     14    0.144043    0.195058
# 14                year                1.00     15    0.003001    0.003001
# 15                year                1.00     16    0.003001    0.003001
# 16                hour                0.25     17  140.201533  295.461527
# 17                hour                0.25     18  140.201533  295.461527
# 18                 day                0.50     19    4.381298    5.671680
# 19                 day                0.50     20    4.381298    5.671680
# 20               month                0.50     21    0.144043    0.195058
# 21               month                0.50     22    0.144043    0.195058
# 22                year                1.00     23    0.003001    0.003001
# 23                year                1.00     24    0.003001    0.003001
# 24                hour                0.25     25  140.201533  295.461527
# 25                 day                0.25     26   17.525192   23.821057
# 26                 day                0.50     27    4.381298    5.671680
# 27                 day                0.50     28    4.381298    5.671680
# 28               month                0.50     29    0.144043    0.195058
# 29               month                0.50     30    0.144043    0.195058
# 30                year                1.00     31    0.003001    0.003001
# 31                year                1.00     32    0.003001    0.003001
#
#        ratio
# 0   2.107406
# 1   2.107406
# 2   1.294521
# 3   1.294521
# 4   1.354167
# 5   1.354167
# 6   1.000000
# 7   1.000000
# 8   2.107406
# 9   2.107406
# 10  1.354167
# 11  1.354167
# 12  1.354167
# 13  1.354167
# 14  1.000000
# 15  1.000000
# 16  2.107406
# 17  2.107406
# 18  1.294521
# 19  1.294521
# 20  1.354167
# 21  1.354167
# 22  1.000000
# 23  1.000000
# 24  2.107406
# 25  1.359247
# 26  1.294521
# 27  1.294521
# 28  1.354167
# 29  1.354167
# 30  1.000000
# 31  1.000000
