# %%
import pandas as pd
from utils import calc_data_size

df_ui = pd.read_csv("stupid_ui.csv")
df_ui["size"] = df_ui.apply(
    lambda x: calc_data_size(
        x["start_year"],
        x["end_year"],
        x["max_lat"],
        x["min_lat"],
        x["max_lon"],
        x["min_lon"],
        x["temporal_resolution"],
        x["spatial_resolution"],
    ),
    axis=1,
)
print("Interested data size:", df_ui["size"].sum(), "GB")
df_ui
# Out:
# Interested data size: 1121.61226272583 GB
#       variable  start_year  end_year  max_lat  min_lat  max_lon  min_lon  \
# 0  temperature        1981      2020       90      -90      180     -180
# 1     pressure        1981      2020       90      -90      180     -180
#
#   temporal_resolution  spatial_resolution  ui_id        size
# 0                hour                0.25      1  560.806131
# 1                hour                0.25      2  560.806131

# %%
from utils import create_metadata_from_ui

df_meta = create_metadata_from_ui(df_ui)
df_meta["file_size"] = df_meta.apply(
    lambda x: calc_data_size(
        x["start_year"],
        x["end_year"],
        x["max_lat"],
        x["min_lat"],
        x["max_lon"],
        x["min_lon"],
        x["actual_temporal_resolution"],
        x["actual_spatial_resolution"],
    ),
    axis=1,
)
print("Total data size after pre-aggregation", df_meta["file_size"].sum(), "GB")
df_meta
# Out:
# Total data size after pre-aggregation 2363.6922124028206 GB
#     ui_id     variable  start_year  end_year  max_lat  min_lat  max_lon  \
# 0       1  temperature        1981      2020       90      -90      180
# 1       1  temperature        1981      2020       90      -90      180
# 2       1  temperature        1981      2020       90      -90      180
# 3       1  temperature        1981      2020       90      -90      180
# 4       1  temperature        1981      2020       90      -90      180
# 5       1  temperature        1981      2020       90      -90      180
# 6       1  temperature        1981      2020       90      -90      180
# 7       1  temperature        1981      2020       90      -90      180
# 8       1  temperature        1981      2020       90      -90      180
# 9       1  temperature        1981      2020       90      -90      180
# 10      1  temperature        1981      2020       90      -90      180
# 11      1  temperature        1981      2020       90      -90      180
# 12      2     pressure        1981      2020       90      -90      180
# 13      2     pressure        1981      2020       90      -90      180
# 14      2     pressure        1981      2020       90      -90      180
# 15      2     pressure        1981      2020       90      -90      180
# 16      2     pressure        1981      2020       90      -90      180
# 17      2     pressure        1981      2020       90      -90      180
# 18      2     pressure        1981      2020       90      -90      180
# 19      2     pressure        1981      2020       90      -90      180
# 20      2     pressure        1981      2020       90      -90      180
# 21      2     pressure        1981      2020       90      -90      180
# 22      2     pressure        1981      2020       90      -90      180
# 23      2     pressure        1981      2020       90      -90      180
#
#     min_lon ui_temporal_resolution  ui_spatial_resolution  \
# 0      -180                   hour                   0.25
# 1      -180                   hour                   0.25
# 2      -180                   hour                   0.25
# 3      -180                   hour                   0.25
# 4      -180                   hour                   0.25
# 5      -180                   hour                   0.25
# 6      -180                   hour                   0.25
# 7      -180                   hour                   0.25
# 8      -180                   hour                   0.25
# 9      -180                   hour                   0.25
# 10     -180                   hour                   0.25
# 11     -180                   hour                   0.25
# 12     -180                   hour                   0.25
# 13     -180                   hour                   0.25
# 14     -180                   hour                   0.25
# 15     -180                   hour                   0.25
# 16     -180                   hour                   0.25
# 17     -180                   hour                   0.25
# 18     -180                   hour                   0.25
# 19     -180                   hour                   0.25
# 20     -180                   hour                   0.25
# 21     -180                   hour                   0.25
# 22     -180                   hour                   0.25
# 23     -180                   hour                   0.25
#
#    actual_temporal_resolution  actual_spatial_resolution   file_size
# 0                        hour                       0.25  560.806131
# 1                        hour                       0.50  420.604599
# 2                        hour                       1.00  105.151150
# 3                         day                       0.25   70.100766
# 4                         day                       0.50   17.525192
# 5                         day                       1.00    4.381298
# 6                       month                       0.25    2.304683
# 7                       month                       0.50    0.576171
# 8                       month                       1.00    0.144043
# 9                        year                       0.25    0.192057
# 10                       year                       0.50    0.048014
# 11                       year                       1.00    0.012004
# 12                       hour                       0.25  560.806131
# 13                       hour                       0.50  420.604599
# 14                       hour                       1.00  105.151150
# 15                        day                       0.25   70.100766
# 16                        day                       0.50   17.525192
# 17                        day                       1.00    4.381298
# 18                      month                       0.25    2.304683
# 19                      month                       0.50    0.576171
# 20                      month                       1.00    0.144043
# 21                       year                       0.25    0.192057
# 22                       year                       0.50    0.048014
# 23                       year                       1.00    0.012004

# %%
# See the ratio

import duckdb

sql = """
SELECT u.*, g.agg_size, g.agg_size / u.size as ratio
FROM df_ui u, (
    SELECT u.ui_id, sum(m.file_size) as agg_size
    FROM df_ui u, df_meta m
    WHERE u.ui_id = m.ui_id
    GROUP BY u.ui_id
) g
WHERE u.ui_id = g.ui_id
"""
df_ui_with_size = duckdb.query(sql).df()
ui_size = df_ui_with_size["size"].sum()
actual_size = df_ui_with_size["agg_size"].sum()
print("ui only size:", ui_size, "GB")
print("including pre-aggregation size:", actual_size, "GB")
print("ratio:", actual_size / ui_size)
df_ui_with_size
# Out:
# ui only size: 1121.61226272583 GB
# including pre-aggregation size: 2363.6922124028206 GB
# ratio: 2.107405821917808
#       variable  start_year  end_year  max_lat  min_lat  max_lon  min_lon  \
# 0  temperature        1981      2020       90      -90      180     -180
# 1     pressure        1981      2020       90      -90      180     -180
#
#   temporal_resolution  spatial_resolution  ui_id        size     agg_size  \
# 0                hour                0.25      1  560.806131  1181.846106
# 1                hour                0.25      2  560.806131  1181.846106
#
#       ratio
# 0  2.107406
# 1  2.107406
